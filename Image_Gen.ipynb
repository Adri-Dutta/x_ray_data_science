# %%
# !chmod +x '/content/script.sh' && cd '/content' && './script.sh' &> /dev/null

# %%
# !cp -r '/tmp/tfgan_logdir/cifar/images' '/content/drive/Shared drives/Data'

# %%
# !zip -r 'P.zip' '/tmp/tfgan_logdir/cifar/images'

# %%
# !git clone https://github.com/tensorflow/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 41708 (delta 26), reused 41 (delta 6), pack-reused 41646
# Receiving objects: 100% (41708/41708), 801.40 MiB | 15.39 MiB/s, done.
# Resolving deltas: 100% (29470/29470), done.
# Checking out files: 100% (5611/5611), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install tensorflow_datasets
# !cd '/content/datasets' && python tensorflow_datasets/scripts/create_new_dataset.py \
  --dataset my_dataset \
  --type image
# Out:
# ...
# 2020-05-09 20:36:01.931920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Dataset generated in /usr/local/lib/python3.6/dist-packages/tensorflow_datasets
# You can start with searching TODO(my_dataset).
# Please check this `https://github.com/tensorflow/datasets/blob/master/docs/add_dataset.md`for details.

# %%
import tensorflow_datasets as tfds
ds= tfds.load(name ='my_dataset', split=None, batch_size=None, shuffle_files=False, download=True)
# Out:
# ...
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
# !rm -r '/usr/local/lib/python3.6/dist-packages/tensorflow_datasets'

# %%
# !pip install tensorflow
# !pip install tensorflow_probability

# %%
# !git clone https://github.com/tensorflow/gan.git

# %%
# !rm -r /root/tensorflow_datasets/my_dataset

# %%
# !pip uninstall tensorflow_datasets

# %%
TFGAN_REPO = '/content/gan'
# !export PYTHONPATH='/content/drive/My Drive/gan/tensorflow_gan/examples':${PYTHONPATH} && export PYTHONPATH='/content/drive/My Drive/gan':${PYTHONPATH} && python '/content/drive/My Drive/gan/tensorflow_gan/examples/cifar/train.py' &> /dev/null

# %%
TFGAN_REPO = '/content/gan'
# !export PYTHONPATH='/content/drive/My Drive/gan/tensorflow_gan/examples':${PYTHONPATH} && export PYTHONPATH='/content/drive/My Drive/gan':${PYTHONPATH} && python '/content/drive/My Drive/gan/tensorflow_gan/examples/cifar/eval.py' --val 1

# %%
# !rm -r '/tmp/tfhub_modules'

# %%
# !cp -r '/tmp/tfgan_logdir' '/content/drive/My Drive/N_3'

# %%
# !cp -r '/content/drive/My Drive/N_3/tfgan_logdir'  '/tmp'

# %%
# !rm -r '/root/tensorflow_datasets'

# %%
# !rm -r '/content/drive/My Drive/gan'
# Out:
# rm: cannot remove '/content/drive/My Drive/gan': No such file or directory

# %%
# !rm -r '/tmp/tfgan_logdir'

# %%
# !cp '/tmp/tfgan_logdir/cifar/events.out.tfevents.1588907168.d1cf973f1072' '/content/drive/My Drive'
# Out:
# ^C

# %%
import tensorflow as tf
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt


img = tf.io.read_file('/content/drive/My Drive/myCow.png')
img = tf.image.decode_png(img, channels=3)
print(tf.image.resize(img,[8,8]))
# img = tf.image.convert_image_dtype(img, tf.float32)
# imgten= tf.convert_to_tensor(img)
# imgrs = tf.reshape(imgten, [1,3072])
# print(imgrs)

# %%
# !find '/tmp/tfgan_logdir/cifar/images' -name 'events*' -exec rm {} \;

# %%
for i in range (0,2):
  # !export PYTHONPATH='/content/drive/My Drive/gan/tensorflow_gan/examples':${PYTHONPATH} && export PYTHONPATH='/content/drive/My Drive/gan':${PYTHONPATH} && python '/content/drive/My Drive/gan/tensorflow_gan/examples/cifar/eval.py' --val i
